# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
pip install stackapi
# Out:
# ...
#   Created wheel for stackapi: filename=StackAPI-0.2.0-py3-none-any.whl size=5858 sha256=9f800e79749695006bbd1562e069e97f4b819387498e88fd82be2b00601a79ae
#   Stored in directory: c:\users\cleme\appdata\local\pip\cache\wheels\de\58\fe\8bab7cf44d8b0bf32e46f1715df2ba8c97d475de95a20985ac
# Successfully built stackapi
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
from datetime import date
from datetime import datetime
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=datetime(2022,2,1), todate=datetime(2022,2,28))
answers = SITE.fetch('answers', fromdate=datetime(2022,2,1), todate=datetime(2022,2,28))
questions
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 289,
#  'total': 0,
#  'items': [{'owner': {'reputation': 115,
#     'user_id': 3938636,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'SAL',
#     'link': 'https://stackoverflow.com/users/3938636/sal'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1667200530,
#    'last_edit_date': 1667200530,
#    'creation_date': 1644888635,
#    'answer_id': 71120172,
#    'question_id': 61578522,
#    'content_license': 'CC BY-SA 4.0'},
#   {'owner': {'reputation': 475,
#     'user_id': 5607920,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/3adcdfbaac16a1556870b0ed857ff651?s=256&d=identicon&r=PG&f=1',
#     'display_name': 'meomeomeo',
#     'link': 'https://stackoverflow.com/users/5607920/meomeomeo'},
#    'is_accepted': False,
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', ids=[6784, 6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 288,
#  'total': 0,
#  'items': [{'owner': {'reputation': 30451,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=256&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778,
#    'content_license': 'CC BY-SA 2.5'}]}

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('badges', ids=[6784, 6473])
answers
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 286,
#  'total': 0,
#  'items': [{'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 6784,
#    'link': 'https://stackoverflow.com/badges/6784/asterisk',
#    'name': 'asterisk'},
#   {'badge_type': 'tag_based',
#    'award_count': 2,
#    'rank': 'gold',
#    'badge_id': 6473,
#    'link': 'https://stackoverflow.com/badges/6473/sql-server-2012',
#    'name': 'sql-server-2012'}]}
