# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
temp = pd.read_csv(r'C:\Users\cleme\Desktop\IronHack\DAFT_1022\module_2\Lab_10_Subsetting-and-Descriptive-Statistics\Temp_States.csv')

# %% [markdown]
# #### Print `temp`.

# %%
# Out:
#          City        State  Temperature
# 0         NYC     New York    19.444444
# 1      Albany     New York     9.444444
# 2     Buffalo     New York     3.333333
# 3    Hartford  Connecticut    17.222222
# 4  Bridgeport  Connecticut    14.444444
# 5      Treton   New Jersey    22.222222
# 6      Newark   New Jersey    20.000000

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
temp.dtypes
# Out:
# City            object
# State           object
# Temperature    float64
# dtype: object

# %%
"""
two text column and also a number one"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
temp.loc[temp['State']=='New York']
# Out:
#       City     State  Temperature
# 0      NYC  New York    19.444444
# 1   Albany  New York     9.444444
# 2  Buffalo  New York     3.333333

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
temp['Temperature'].mean()
# Out:
# 15.15873015873016

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
temp.loc[temp['Temperature'] > 15]
# Out:
#        City        State  Temperature
# 0       NYC     New York    19.444444
# 3  Hartford  Connecticut    17.222222
# 5    Treton   New Jersey    22.222222
# 6    Newark   New Jersey    20.000000

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
temp[temp['Temperature']>15]['City']
# Out:
# 0         NYC
# 3    Hartford
# 5      Treton
# 6      Newark
# Name: City, dtype: object

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
temp[(temp['Temperature']>15) & (temp['Temperature']<20)]['City']
# Out:
# 0         NYC
# 3    Hartford
# Name: City, dtype: object

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
temp[['State', 'Temperature']].groupby('State').agg('mean')
# Out:
#              Temperature
# State
# Connecticut    15.833333
# New Jersey     21.111111
# New York       10.740741

# %%
temp[['State', 'Temperature']].groupby('State').agg('std')
# Out:
#              Temperature
# State
# Connecticut     1.964186
# New Jersey      1.571348
# New York        8.133404

# %% [markdown]
# #  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
employees = pd.read_csv(r'C:\Users\cleme\Desktop\IronHack\DAFT_1022\module_2\Lab_10_Subsetting-and-Descriptive-Statistics/Employees.csv')

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
employees.dtypes
# Out:
# Department    object
# Education     object
# Title         object
# Name          object
# Years          int64
# Salary         int64
# dtype: object

# %% [raw]
# # """
# 4 texts columns and 2 numbers columns
# """

# %% [markdown]
# #### What's the average salary in this company?

# %%
employees['Salary'].mean()
# Out:
# 73.528

# %% [markdown]
# #### What's the highest salary?

# %%
employees['Salary'].max()
# Out:
# 120

# %% [markdown]
# #### What's the lowest salary?

# %%
employees['Salary'].min()
# Out:
# 30

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
employees[employees['Salary']==employees['Salary'].min()]['Name']
# Out:
# 27         Sean
# 106        Luke
# 128        Adam
# 139        Rick
# 214        Neil
# 266      Marcel
# 452    Augustin
# Name: Name, dtype: object

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
employees[employees['Name']=='David']
# Out:
#     Department Education      Title   Name  Years  Salary
# 0        Admin    Master  associate  David      4      58
# 124         IT  Bachelor         VP  David      3      31

# %% [markdown]
# #### Could you return only David's salary?

# %%
employees[employees['Name']=='David']['Salary']
# Out:
# 0      58
# 124    31
# Name: Salary, dtype: int64

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
employees[employees['Title']=='associate']
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 1           IT    Master  associate    Thomas      7      45
# 2        Admin    Master  associate     Diana     10      52
# 7           HR    Master  associate     Carol     14      53
# 8        Admin       PhD  associate      Jean      8      50
# ..         ...       ...        ...       ...    ...     ...
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 491      Admin       PhD  associate     Alice      8      37
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [158 rows x 6 columns]

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
employees[employees['Title']=='associate'].head(3)
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %%
# Method 2
employees[employees['Title']=='associate'].iloc[0:3]
# Out:
#   Department Education      Title    Name  Years  Salary
# 0      Admin    Master  associate   David      4      58
# 1         IT    Master  associate  Thomas      7      45
# 2      Admin    Master  associate   Diana     10      52

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
employees[(employees['Title']=='associate')&(employees['Salary']>55)]
# Out:
#     Department Education      Title      Name  Years  Salary
# 0        Admin    Master  associate     David      4      58
# 9        Admin    Master  associate    Kareem      3     104
# 10       Admin    Master  associate   Cynthia      1     114
# 16       Admin  Bachelor  associate    Shanon      1      99
# 18       Admin  Bachelor  associate     Megan      9      79
# ..         ...       ...        ...       ...    ...     ...
# 476      Admin       PhD  associate      Greg      8      93
# 477         HR       PhD  associate   Phillip     11     113
# 486         IT  Bachelor  associate       Jay     14      58
# 487         HR    Master  associate  Patricia     10     110
# 494      Sales  Bachelor  associate   Vanessa     11     118
#
# [104 rows x 6 columns]

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
employees[['Years', 'Salary']].groupby('Years').agg({'Salary':'mean'})
# Out:
#           Salary
# Years
# 1      75.863636
# 2      75.857143
# 3      74.571429
# 4      77.129032
# 5      73.857143
# 6      72.382353
# 7      73.840000
# 8      64.250000
# 9      76.741935
# 10     73.351351
# 11     74.866667
# 12     73.454545
# 13     71.935484
# 14     70.968750
# 15     69.758621

# %% [markdown]
# ####  What is the average salary per title?

# %%
employees[['Title', 'Salary']].groupby('Title').mean()
# Out:
#               Salary
# Title
# Analyst    73.703911
# VP         72.907975
# associate  73.968354

# %% [markdown]
# ####  Find the salary quartiles.

# %%
employees['Salary'].describe()
# Out:
# count    500.000000
# mean      73.528000
# std       26.890061
# min       30.000000
# 25%       50.000000
# 50%       72.000000
# 75%       97.000000
# max      120.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
employees.groupby('Department').min(numeric_only=True)
# Out:
#             Years  Salary
# Department
# Admin           1      30
# HR              1      30
# IT              1      30
# Sales           1      30

# %%
employees.groupby('Department').max(numeric_only=True)
# Out:
#             Years  Salary
# Department
# Admin          15     120
# HR             15     119
# IT             15     120
# Sales          15     120

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
employees.groupby('Department').std()
# Out:
#                Years     Salary
# Department
# Admin       4.706344  25.734615
# HR          4.292397  26.522423
# IT          4.472393  27.406101
# Sales       4.358741  27.819340

# %% [markdown]
# # Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
orders = pd.read_csv(r'C:\Users\cleme\Downloads\Orders - Orders.csv')

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
orders.dtypes
# Out:
# Unnamed: 0             float64
# InvoiceNo              float64
# StockCode               object
# year                   float64
# month                  float64
# day                    float64
# hour                   float64
# Description             object
# Quantity               float64
# InvoiceDate     datetime64[ns]
# UnitPrice              float64
# CustomerID             float64
# Country                 object
# amount_spent           float64
# dtype: object

# %%
orders.describe()
# Out:
#           Unnamed: 0      InvoiceNo           year          month  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean   278465.221859  560617.126645    2010.934259       7.612537
# std    152771.368303   13106.167695       0.247829       3.416527
# min         0.000000  536365.000000    2010.000000       1.000000
# 25%    148333.750000  549234.000000    2011.000000       5.000000
# 50%    284907.500000  561893.000000    2011.000000       8.000000
# 75%    410079.250000  572090.000000    2011.000000      11.000000
# max    541908.000000  581587.000000    2011.000000      12.000000
#
#                  day           hour       Quantity      UnitPrice  \
# count  397924.000000  397924.000000  397924.000000  397924.000000
# mean        3.614555      12.728247      13.021823       3.116174
# std         1.928274       2.273535     180.420210      22.096788
# min         1.000000       6.000000       1.000000       0.000000
# ...

# %%
"""
your comments here
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
orders['UnitPrice'].mean()
# Out:
# 3.116174480549152

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %%
orders['UnitPrice'].min()
# Out:
# 0.0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
orders[orders['Country']=='Spain']['CustomerID'].unique()
# Out:
# array([12557., 17097., 12540., 12551., 12484., 12539., 12510., 12421.,
#        12502., 12462., 12507., 12541., 12547., 12597., 12545., 12596.,
#        12354., 12417., 12455., 12450., 12548., 12556., 12550., 12546.,
#        12454., 12448., 12544., 12538., 12445., 12442.])

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
len(orders[orders['Country']=='Spain']['CustomerID'].unique())
# Out:
# 30

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
tot = orders.groupby('CustomerID')['Quantity'].agg('sum')

# %%
tot2 = tot.to_frame()
tot2.head()
# Out:
#             Quantity
# CustomerID
# 12346.0      74215.0
# 12347.0       2458.0
# 12348.0       2341.0
# 12349.0        631.0
# 12350.0        197.0

# %%
tot2[tot2['Quantity']>50]
# Out:
#             Quantity
# CustomerID
# 12346.0      74215.0
# 12347.0       2458.0
# 12348.0       2341.0
# 12349.0        631.0
# 12350.0        197.0
# ...              ...
# 18278.0         66.0
# 18281.0         54.0
# 18282.0        103.0
# 18283.0       1397.0
# 18287.0       1586.0
#
# [4091 rows x 1 columns]

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
orders[(orders['Country']=='Spain') & (orders['Quantity']>50)].head()
# Out:
#       Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 4250      6421.0   536944.0   22383.0  2010.0   12.0  5.0  12.0
# 4251      6422.0   536944.0   22384.0  2010.0   12.0  5.0  12.0
# 4252      6423.0   536944.0   20727.0  2010.0   12.0  5.0  12.0
# 4253      6424.0   536944.0   20725.0  2010.0   12.0  5.0  12.0
# 4254      6425.0   536944.0   20728.0  2010.0   12.0  5.0  12.0
#
#                   Description  Quantity         InvoiceDate  UnitPrice  \
# 4250   lunch bag suki  design      70.0 2010-12-03 12:20:00       1.65
# 4251  lunch bag pink polkadot     100.0 2010-12-03 12:20:00       1.45
# 4252  lunch bag  black skull.      60.0 2010-12-03 12:20:00       1.65
# 4253  lunch bag red retrospot      70.0 2010-12-03 12:20:00       1.65
# 4254      lunch bag cars blue     100.0 2010-12-03 12:20:00       1.45
#
#       CustomerID Country  amount_spent
# 4250     12557.0   Spain         115.5
# 4251     12557.0   Spain         145.0
# ...

# %% [markdown]
# #### Select all free orders.

# %%
orders[orders['amount_spent']==0]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 6914        9302.0   537197.0   22841.0  2010.0   12.0  7.0  14.0
# 22539      33576.0   539263.0   22580.0  2010.0   12.0  4.0  14.0
# 25379      40089.0   539722.0   22423.0  2010.0   12.0  2.0  13.0
# 29080      47068.0   540372.0   22090.0  2011.0    1.0  4.0  16.0
# 29082      47070.0   540372.0   22553.0  2011.0    1.0  4.0  16.0
# 34494      56674.0   541109.0   22168.0  2011.0    1.0  4.0  15.0
# 53788      86789.0   543599.0    84535B  2011.0    2.0  4.0  13.0
# 85671     130188.0   547417.0   22062.0  2011.0    3.0  3.0  10.0
# 92875     139453.0   548318.0   22055.0  2011.0    3.0  3.0  12.0
# 97430     145208.0   548871.0   22162.0  2011.0    4.0  1.0  14.0
# 107192    157042.0   550188.0   22636.0  2011.0    4.0  4.0  18.0
# 128641    187613.0   553000.0   47566.0  2011.0    5.0  4.0  15.0
# 137127    198383.0   554037.0   22619.0  2011.0    5.0  5.0  14.0
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
orders[orders['Description'].str.startswith('lunch bag')]
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 93            93.0   536378.0   20725.0  2010.0   12.0  3.0   9.0
# 172          174.0   536385.0   22662.0  2010.0   12.0  3.0   9.0
# 354          363.0   536401.0   22662.0  2010.0   12.0  3.0  11.0
# 359          368.0   536401.0   20725.0  2010.0   12.0  3.0  11.0
# 360          369.0   536401.0   22382.0  2010.0   12.0  3.0  11.0
# ...            ...        ...       ...     ...    ...  ...   ...
# 397465    540436.0   581486.0   23207.0  2011.0   12.0  5.0   9.0
# 397713    541695.0   581538.0   20727.0  2011.0   12.0  5.0  11.0
# 397714    541696.0   581538.0   20725.0  2011.0   12.0  5.0  11.0
# 397877    541862.0   581581.0   23681.0  2011.0   12.0  5.0  12.0
# 397880    541865.0   581583.0   20725.0  2011.0   12.0  5.0  12.0
#
#                         Description  Quantity         InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot      10.0 2010-12-01 09:37:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
orders[(orders['Description'].str.startswith('lunch bag'))&(orders['year']==2011)].head()
# Out:
#        Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 26340     42678.0   540015.0   20725.0  2011.0    1.0  2.0  11.0
# 26341     42679.0   540015.0   20726.0  2011.0    1.0  2.0  11.0
# 26512     42851.0   540023.0   22382.0  2011.0    1.0  2.0  12.0
# 26513     42852.0   540023.0   20726.0  2011.0    1.0  2.0  12.0
# 26860     43616.0   540098.0   22384.0  2011.0    1.0  2.0  15.0
#
#                      Description  Quantity         InvoiceDate  UnitPrice  \
# 26340    lunch bag red retrospot      10.0 2011-01-04 11:40:00       1.65
# 26341         lunch bag woodland      10.0 2011-01-04 11:40:00       1.65
# 26512  lunch bag spaceboy design       2.0 2011-01-04 12:58:00       1.65
# 26513         lunch bag woodland       1.0 2011-01-04 12:58:00       1.65
# 26860    lunch bag pink polkadot       1.0 2011-01-04 15:50:00       1.65
#
#        CustomerID         Country  amount_spent
# 26340     13319.0  United Kingdom         16.50
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
Spain = orders[orders['Country']=='Spain']
Spain['amount_spent'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
orders[orders['month']==8].head()
# Out:
#         Unnamed: 0  InvoiceNo StockCode    year  month  day  hour  \
# 199475    285421.0   561904.0   22075.0  2011.0    8.0  1.0   8.0
# 199476    285422.0   561904.0    85049E  2011.0    8.0  1.0   8.0
# 199477    285423.0   561905.0   21385.0  2011.0    8.0  1.0   9.0
# 199478    285424.0   561905.0    84970L  2011.0    8.0  1.0   9.0
# 199479    285425.0   561905.0    84970S  2011.0    8.0  1.0   9.0
#
#                               Description  Quantity         InvoiceDate  \
# 199475        6 ribbons elegant christmas      96.0 2011-08-01 08:30:00
# 199476          scandinavian reds ribbons     156.0 2011-08-01 08:30:00
# 199477    ivory hanging decoration  heart      24.0 2011-08-01 09:31:00
# 199478   single heart zinc t-light holder      12.0 2011-08-01 09:31:00
# 199479  hanging heart zinc t-light holder      12.0 2011-08-01 09:31:00
#
#         UnitPrice  CustomerID         Country  amount_spent
# 199475       1.45     17941.0  United Kingdom        139.20
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
o=orders[orders['month']==8].groupby('Country').agg('count')
o['InvoiceNo'].sort_values
# Out:
# <bound method Series.sort_values of Country
# Australia            107
# Austria               88
# Belgium              194
# Canada                 5
# Channel Islands      140
# Denmark               16
# EIRE                 593
# Finland               61
# France               569
# Germany              795
# Iceland               22
# Israel               171
# Italy                 95
# Malta                 55
# Netherlands          280
# Norway                77
# Poland                17
# Portugal              41
# Spain                252
# Sweden                40
# Switzerland          267
# United Kingdom     23105
# Unspecified           23
# Name: InvoiceNo, dtype: int64>

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
orders[['Country', 'amount_spent']].groupby('Country').mean()
# Out:
#                       amount_spent
# Country
# Australia               116.895620
# Austria                  25.624824
# Bahrain                  32.258824
# Belgium                  20.283772
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          27.340160
# Cyprus                   22.134169
# Czech Republic           33.069600
# Denmark                  49.882474
# EIRE                     36.687745
# European Community       21.670833
# Finland                  32.913985
# France                   25.056827
# Germany                  25.311562
# Greece                   32.831172
# Iceland                  23.681319
# Israel                   29.119718
# Italy                    23.064960
# Japan                   116.561900
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    24.335625
# Netherlands             120.798282
# Norway                   33.736418
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
orders['UnitPrice'].max()
# Out:
# 8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
orders[['amount_spent', 'year']].groupby('year').agg('mean')
# Out:
#         amount_spent
# year
# 2010.0     21.892733
# 2011.0     22.430074
